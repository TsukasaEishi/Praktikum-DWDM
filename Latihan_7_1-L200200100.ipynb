# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
gender_submission = pd.read_csv('gender_submission.csv')

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
column_names = train_data.columns
for column in column_names:
    print(column + ' - ' + str(train_data[column].isnull().sum()))
# Out:
# PassengerId - 0
# Survived - 0
# Pclass - 0
# Name - 0
# Sex - 0
# Age - 177
# SibSp - 0
# Parch - 0
# Ticket - 0
# Fare - 0
# Cabin - 687
# Embarked - 2

# %%
train_data['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
dt = train_data['Survived'].value_counts()
plt = dt.plot(kind = 'bar', rot=0)
plt.set_xlabel('Selamat atau Tidak Selamat')
plt.set_ylabel('Jumlah Penumpang')
# Out:
# Text(0, 0.5, 'Jumlah Penumpang')

# %%
dt = train_data[['Pclass','Survived']].groupby('Pclass').mean().Survived
plt = dt.plot(kind = 'bar', rot=0, color=['red','green','blue'])
plt.set_xlabel('Kelas')
plt.set_ylabel('Probabilitas')
# Out:
# Text(0, 0.5, 'Probabilitas')

# %%
sns.catplot(x='Pclass', col = 'Sex', data = train_data, kind = 'count')

# %%
train_data= train_data.drop(columns=['Ticket','PassengerId','Cabin'])
train_data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
train_data['FamilySize'] = train_data['SibSp'] + train_data['Parch'] + 1
train_data.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked  FamilySize
# 0    male  22.0      1      0   7.2500        S           2
# 1  female  38.0      1      0  71.2833        C           2
# 2  female  26.0      0      0   7.9250        S           1
# 3  female  35.0      1      0  53.1000        S           2
# 4    male  35.0      0      0   8.0500        S           1

# %%
train_data['Sex'] = train_data['Sex'].map({'male':0, 'female':1})
train_data['Embarked'] = train_data['Embarked'].map({'C':0, 'Q':1, 'S':2})
train_data.head()
# Out:
#    Survived  Pclass                                               Name  Sex  \
# 0         0       3                            Braund, Mr. Owen Harris    0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1
# 2         1       3                             Heikkinen, Miss. Laina    1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1
# 4         0       3                           Allen, Mr. William Henry    0
#
#     Age  SibSp  Parch     Fare  Embarked  FamilySize
# 0  22.0      1      0   7.2500       2.0           2
# 1  38.0      1      0  71.2833       0.0           2
# 2  26.0      0      0   7.9250       2.0           1
# 3  35.0      1      0  53.1000       2.0           2
# 4  35.0      0      0   8.0500       2.0           1

# %%
train_data['Title'] = train_data['Name'].str.extract('([A-Za-z]+)\.', expand= False)
train_data = train_data.drop(columns= 'Name')
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         0       3    0  22.0      1      0   7.2500       2.0           2
# 1         1       1    1  38.0      1      0  71.2833       0.0           2
# 2         1       3    1  26.0      0      0   7.9250       2.0           1
# 3         1       1    1  35.0      1      0  53.1000       2.0           2
# 4         0       3    0  35.0      0      0   8.0500       2.0           1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr

# %%
train_data['Title'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
train_data['Title'] = train_data['Title'].replace(['Dr','Rev','Col','Major','Countess','Sir','Jonkheer','Lady','Capt','Don'], 'others')
train_data['Title'] = train_data['Title'].replace('Ms','Miss')
train_data['Title'] = train_data['Title'].replace('Mme','Mrs')
train_data['Title'] = train_data['Title'].replace('Mlle','Miss')

# %%
plt = train_data['Title'].value_counts().sort_index().plot(kind = 'bar', color=['blue','orange','green','red','purple'])
plt.set_xlabel('Gelar')
plt.set_ylabel('Jumlah Penumpang')
# Out:
# Text(0, 0.5, 'Jumlah Penumpang')

# %%
corr_matrix = train_data.corr()
# Out:
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\624221814.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = train_data.corr()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,8))
sns.heatmap(data = corr_matrix, cmap='BrBG', annot=True, linewidths= 0.2)
# Out:
# <AxesSubplot: >

# %%
missing = train_data['Embarked'].isnull().sum()
print("Jumlah data kosong pada atribut Embarked: ",missing)
# Out:
# Jumlah data kosong pada atribut Embarked:  2

# %%
plt = train_data['Embarked'].value_counts().sort_index().plot(kind = 'bar',  color=['red','green','blue'],rot=0)
plt.set_xlabel('Embarked')
plt.set_ylabel('Jumlah Penumpang')
# Out:
# Text(0, 0.5, 'Jumlah Penumpang')

# %%
train_data['Embarked'] = train_data['Embarked'].fillna(2)
train_data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0         0       3    0  22.0      1      0   7.2500       2.0           2
# 1         1       1    1  38.0      1      0  71.2833       0.0           2
# 2         1       3    1  26.0      0      0   7.9250       2.0           1
# 3         1       1    1  35.0      1      0  53.1000       2.0           2
# 4         0       3    0  35.0      0      0   8.0500       2.0           1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr

# %%
NaN_indexes = train_data['Age'][train_data['Age'].isnull()].index
print(NaN_indexes)
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0           0       3    0  22.0      1      0   7.2500       2.0           2
# 1           1       1    1  38.0      1      0  71.2833       0.0           2
# 2           1       3    1  26.0      0      0   7.9250       2.0           1
# 3           1       1    1  35.0      1      0  53.1000       2.0           2
# 4           0       3    0  35.0      0      0   8.0500       2.0           1
# ..        ...     ...  ...   ...    ...    ...      ...       ...         ...
# 886         0       2    0  27.0      0      0  13.0000       2.0           1
# 887         1       1    1  19.0      0      0  30.0000       2.0           1
# 888         0       3    1   NaN      1      2  23.4500       2.0           4
# 889         1       1    0  26.0      0      0  30.0000       0.0           1
# 890         0       3    0  32.0      0      0   7.7500       1.0           1
#
#       Title
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
# ..      ...
# 886  others
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
#
# [891 rows x 10 columns]

# %%
for i in NaN_indexes:
    pred_age = train_data['Age'][((train_data.SibSp == train_data.iloc[i]["SibSp"]) & (train_data.Parch == train_data.iloc[i]["Parch"]) & (train_data.Pclass == train_data.iloc[i]["Pclass"]))].median()

    if np.isnan(pred_age):
        train_data['Age'].iloc[i] = train_data['Age'].median()
    else:
        train_data['Age'].iloc[i] = pred_age

# train_data.fillna(value=train_data['SibSp','Parch','Pclass'].mean())
# Out:
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# C:\Users\iwan1\AppData\Local\Temp\ipykernel_9384\273174090.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Age'].iloc[i] = pred_age
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 2
#       1 for i in NaN_indexes:
# ----> 2     pred_age = train_data['Age'][((train_data['SibSp'] == train_data.iloc[i]['SibSp']) & (train_data['Parch'] == train_data.iloc[i]['Parch']) & (train_data['Pclass'] == train_data.iloc[i]['Pclass']))].median()
#       4     if np.isnan(pred_age):
#       5         train_data['Age'].iloc[i] = train_data['Age'].median()
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11917, in NDFrame._add_numeric_operations.<locals>.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11899 @doc(
#   11900     _num_doc,
#   11901     desc="Return the median of the values over the requested axis.",
#    (...)
#   11915     **kwargs,
#   11916 ):
# > 11917     return NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11413, in NDFrame.median(self, axis, skipna, level, numeric_only, **kwargs)
#   11405 def median(
#   11406     self,
#   11407     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   11411     **kwargs,
#   11412 ) -> Series | float:
# > 11413     return self._stat_function(
#   11414         "median", nanops.nanmedian, axis, skipna, level, numeric_only, **kwargs
#   11415     )
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11353, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   11343     warnings.warn(
#   11344         "Using the level keyword in DataFrame and Series aggregations is "
#   11345         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   11348         stacklevel=find_stack_level(),
#   11349     )
#   11350     return self._agg_by_level(
#   11351         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   11352     )
# > 11353 return self._reduce(
#   11354     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11355 )
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4816, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4812     raise NotImplementedError(
#    4813         f"Series.{name} does not implement {kwd_name}."
#    4814     )
#    4815 with np.errstate(all="ignore"):
# -> 4816     return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     153         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154 else:
# --> 155     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 return result
#
# File c:\Users\iwan1\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:760, in nanmedian(values, axis, skipna, mask)
#     758 if not is_float_dtype(values.dtype):
#     759     try:
# --> 760         values = values.astype("f8")
#     761     except ValueError as err:
#     762         # e.g. "could not convert string to float: 'a'"
#     763         raise TypeError(str(err)) from err
#
# TypeError: float() argument must be a string or a real number, not 'method'

# %%
train_data.isnull().sum()
# Out:
# Survived        0
# Pclass          0
# Sex             0
# Age           142
# SibSp           0
# Parch           0
# Fare            0
# Embarked        0
# FamilySize      0
# Title           0
# dtype: int64

# %%
train_data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  FamilySize  \
# 0           0       3    0  22.0      1      0   7.2500       2.0           2
# 1           1       1    1  38.0      1      0  71.2833       0.0           2
# 2           1       3    1  26.0      0      0   7.9250       2.0           1
# 3           1       1    1  35.0      1      0  53.1000       2.0           2
# 4           0       3    0  35.0      0      0   8.0500       2.0           1
# ..        ...     ...  ...   ...    ...    ...      ...       ...         ...
# 886         0       2    0  27.0      0      0  13.0000       2.0           1
# 887         1       1    1  19.0      0      0  30.0000       2.0           1
# 888         0       3    1   NaN      1      2  23.4500       2.0           4
# 889         1       1    0  26.0      0      0  30.0000       0.0           1
# 890         0       3    0  32.0      0      0   7.7500       1.0           1
#
#       Title
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
# ..      ...
# 886  others
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
#
# [891 rows x 10 columns]
